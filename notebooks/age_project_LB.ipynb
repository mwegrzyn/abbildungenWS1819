# %% [markdown]
# ## Perception of begin old
#
# Analysis of a dataset taken from https://github.com/tomeru/sideProjects/tree/master/feelingOld, data collected by Tomer Ullman
#
# ...

# %% [markdown]
# ### import modules

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /home/brain/.conda/envs/abbildungen/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/brain/.conda/envs/abbildungen/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# ### load data

# %%
dataset = '../data/feelingOld.csv'

# %%
# pandas read csv files

# %% [markdown]
# ### ...

# %%
old=pd.read_csv(dataset)

# %%
old
# Out:
#                                                Consent  ageFeel  oldBegin  \
# 0    Yes, I am at least 18 years of age, have read ...        4        55
# 1    Yes, I am at least 18 years of age, have read ...        5        40
# 2    Yes, I am at least 18 years of age, have read ...        5        40
# 3    Yes, I am at least 18 years of age, have read ...        2        40
# 4    Yes, I am at least 18 years of age, have read ...        5        50
# 5    Yes, I am at least 18 years of age, have read ...        5        40
# 6    Yes, I am at least 18 years of age, have read ...        5        30
# 7    Yes, I am at least 18 years of age, have read ...        1        40
# 8    Yes, I am at least 18 years of age, have read ...        5        30
# 9    Yes, I am at least 18 years of age, have read ...        3        50
# 10   Yes, I am at least 18 years of age, have read ...        5        45
# 11   Yes, I am at least 18 years of age, have read ...        5        55
# ...

# %%
sns.set_context('talk')
sns.set_style('ticks')

# %%
sns.scatterplot(data=old, x='age', y='oldBegin')

# %%
sns.regplot(x='age', y='oldBegin', data=old)
# Out:
# /home/brain/.conda/envs/abbildungen/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.regplot(x='age', y='oldReally', data=old)
# Out:
# /home/brain/.conda/envs/abbildungen/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.regplot(x='age', y='oldReally', data=old)
sns.regplot(x='age', y='oldBegin', data=old)
# Out:
# /home/brain/.conda/envs/abbildungen/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Zwei Gruppen nach Alter sortiert

# %%
L1 = []
for item in old["age"][::30]:
    L1.append(item)
L2 = []
for item in old["age"][31::50]:
    L2.append(item)

# %%
old.describe()
# Out:
#           ageFeel    oldBegin   oldReally         age    numChild
# count  195.000000  195.000000  195.000000  195.000000  195.000000
# mean     4.025641   48.128205   67.887179   36.805128    0.933333
# std      1.237040   12.600891   14.348303   12.116402    1.188721
# min      1.000000   20.000000   18.000000   20.000000    0.000000
# 25%      3.000000   40.000000   60.000000   28.000000    0.000000
# 50%      4.000000   50.000000   70.000000   33.000000    0.000000
# 75%      5.000000   60.000000   80.000000   43.500000    2.000000
# max      7.000000   80.000000  112.000000   79.000000    5.000000

# %%
type(old["age"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## zwei Objekte für die Altersgruppen min - Median und Median - max

# %%
old['age'].median()
# Out:
# 33.0

# %%
old_kl33=old["age"]<33

# %%
old_gr33=old["age"]>33

# %%
old.loc[:,'ageBins'] = pd.cut(old['age'],(0,20,79))

# %%
old
# Out:
#                                                Consent  ageFeel  oldBegin  \
# 0    Yes, I am at least 18 years of age, have read ...        4        55
# 1    Yes, I am at least 18 years of age, have read ...        5        40
# 2    Yes, I am at least 18 years of age, have read ...        5        40
# 3    Yes, I am at least 18 years of age, have read ...        2        40
# 4    Yes, I am at least 18 years of age, have read ...        5        50
# 5    Yes, I am at least 18 years of age, have read ...        5        40
# 6    Yes, I am at least 18 years of age, have read ...        5        30
# 7    Yes, I am at least 18 years of age, have read ...        1        40
# 8    Yes, I am at least 18 years of age, have read ...        5        30
# 9    Yes, I am at least 18 years of age, have read ...        3        50
# 10   Yes, I am at least 18 years of age, have read ...        5        45
# 11   Yes, I am at least 18 years of age, have read ...        5        55
# ...

# %%
old_kl33
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16     False
# 17      True
# 18      True
# 19     False
# 20     False
# 21     False
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27     False
# 28      True
# 29     False
#        ...
# 165     True
# 166     True
# 167     True
# 168    False
# 169    False
# 170     True
# 171    False
# 172     True
# 173    False
# 174    False
# 175     True
# 176     True
# 177    False
# 178    False
# 179    False
# 180     True
# 181     True
# 182    False
# 183     True
# 184    False
# 185     True
# 186    False
# 187    False
# 188    False
# 189     True
# 190     True
# 191    False
# 192    False
# 193    False
# 194    False
# Name: age, Length: 195, dtype: bool

# %%
old[old_kl33]
# Out:
#                                                Consent  ageFeel  oldBegin  \
# 0    Yes, I am at least 18 years of age, have read ...        4        55
# 2    Yes, I am at least 18 years of age, have read ...        5        40
# 6    Yes, I am at least 18 years of age, have read ...        5        30
# 11   Yes, I am at least 18 years of age, have read ...        5        55
# 12   Yes, I am at least 18 years of age, have read ...        6        55
# 13   Yes, I am at least 18 years of age, have read ...        3        65
# 14   Yes, I am at least 18 years of age, have read ...        3        45
# 15   Yes, I am at least 18 years of age, have read ...        2        28
# 17   Yes, I am at least 18 years of age, have read ...        3        40
# 18   Yes, I am at least 18 years of age, have read ...        5        30
# 22   Yes, I am at least 18 years of age, have read ...        5        40
# 23   Yes, I am at least 18 years of age, have read ...        3        38
# ...

# %%
old.loc

# %%
sns.regplot(x='age', y='oldReally', data=old[old_kl33])
# Out:
# /home/brain/.conda/envs/abbildungen/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.regplot(x='age', y='oldReally', data=old[old_gr33])
# Out:
# /home/brain/.conda/envs/abbildungen/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
