# %% [markdown]
# # Perception of begin old
#
# Analysis of a dataset taken from https://github.com/tomeru/sideProjects/tree/master/feelingOld, data collected by Tomer Ullman
#
# ...

# %% [markdown]
# ### import modules

# %%
import pandas as pd
# Out:
# /home/brain/.conda/envs/abbildungen/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/brain/.conda/envs/abbildungen/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# ### load data

# %%
feelingold = pd.read_csv('../data/feelingOld.csv')

# %%
feelingold
# Out:
#                                                Consent  ageFeel  oldBegin  \
# 0    Yes, I am at least 18 years of age, have read ...        4        55
# 1    Yes, I am at least 18 years of age, have read ...        5        40
# 2    Yes, I am at least 18 years of age, have read ...        5        40
# 3    Yes, I am at least 18 years of age, have read ...        2        40
# 4    Yes, I am at least 18 years of age, have read ...        5        50
# 5    Yes, I am at least 18 years of age, have read ...        5        40
# 6    Yes, I am at least 18 years of age, have read ...        5        30
# 7    Yes, I am at least 18 years of age, have read ...        1        40
# 8    Yes, I am at least 18 years of age, have read ...        5        30
# 9    Yes, I am at least 18 years of age, have read ...        3        50
# 10   Yes, I am at least 18 years of age, have read ...        5        45
# 11   Yes, I am at least 18 years of age, have read ...        5        55
# ...

# %% [markdown]
# ### ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-6d87f1ac54eb> in <module>()
# ----> 1 sns.scatterplot(data=feelingold, x='age', y='ageFeel')
#
# NameError: name 'sns' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-f4c99839b23b> in <module>()
# ----> 1 sns.set_context('talk')
#       2 sns.set_style('ticks')
#
# NameError: name 'sns' is not defined

# %%
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_context('talk')
sns.set_style('ticks')

# %%
sns.scatterplot(data=feelingold, x='age', y='ageFeel')

# %%
# Out:
#   File "<ipython-input-19-83497227a1a3>", line 1
#     Männer = subset(feelingold, gender = Male |gender = male)
#                                                       ^
# SyntaxError: invalid syntax

# %%
[x.lower() for x in feelingold.loc [:,'gender']]
# Out:
# ['female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
# ...

# %%
np.unique(feelingold.loc[:,'gender'])
# Out:
# array(['FEMALE', 'Femail', 'Female', 'Female ', 'female', 'male'],
#       dtype=object)

# %%
feelingold['gender'][feelingold['gender']== 'mael'] = 'male'
# Out:
# /home/brain/.conda/envs/abbildungen/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
feelingold['gender'][feelingold['gender']== 'FEMALE'] = 'female'
feelingold['gender'][feelingold['gender']== 'Female'] = 'female'
feelingold['gender'][feelingold['gender']== 'femail'] = 'female'
feelingold['gender'][feelingold['gender']== 'Female '] = 'female'
feelingold['gender'][feelingold['gender']== 'Femail'] = 'female'
# Out:
# /home/brain/.conda/envs/abbildungen/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/brain/.conda/envs/abbildungen/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/brain/.conda/envs/abbildungen/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
np.unique(feelingold.loc[:,'gender'])
# Out:
# array(['female', 'male'], dtype=object)

# %%
feelingold
# Out:
#                                                Consent  ageFeel  oldBegin  \
# 0    Yes, I am at least 18 years of age, have read ...        4        55
# 1    Yes, I am at least 18 years of age, have read ...        5        40
# 2    Yes, I am at least 18 years of age, have read ...        5        40
# 3    Yes, I am at least 18 years of age, have read ...        2        40
# 4    Yes, I am at least 18 years of age, have read ...        5        50
# 5    Yes, I am at least 18 years of age, have read ...        5        40
# 6    Yes, I am at least 18 years of age, have read ...        5        30
# 7    Yes, I am at least 18 years of age, have read ...        1        40
# 8    Yes, I am at least 18 years of age, have read ...        5        30
# 9    Yes, I am at least 18 years of age, have read ...        3        50
# 10   Yes, I am at least 18 years of age, have read ...        5        45
# 11   Yes, I am at least 18 years of age, have read ...        5        55
# ...

# %%
male = feelingold[feelingold['gender']== 'male']
female = feelingold[feelingold['gender']== 'female']

# %%
sns.barplot(female.mean()
# Out:
# ageFeel       4.337838
# oldBegin     49.797297
# oldReally    70.783784
# age          39.378378
# numChild      1.364865
# dtype: float64

# %%
means = {female}
# Out:
#                                                Consent  ageFeel  oldBegin  \
# 0    Yes, I am at least 18 years of age, have read ...        4        55
# 1    Yes, I am at least 18 years of age, have read ...        5        40
# 2    Yes, I am at least 18 years of age, have read ...        5        40
# 3    Yes, I am at least 18 years of age, have read ...        2        40
# 6    Yes, I am at least 18 years of age, have read ...        5        30
# 7    Yes, I am at least 18 years of age, have read ...        1        40
# 10   Yes, I am at least 18 years of age, have read ...        5        45
# 12   Yes, I am at least 18 years of age, have read ...        6        55
# 13   Yes, I am at least 18 years of age, have read ...        3        65
# 16   Yes, I am at least 18 years of age, have read ...        4        70
# 19   Yes, I am at least 18 years of age, have read ...        5        45
# 25   Yes, I am at least 18 years of age, have read ...        4        27
# ...
